# %%
# !pip install -U git+https://github.com/huggingface/transformers.git
# !pip install -U accelerate==0.27.1
# !pip install -U datasets>=2.16.1
# !pip install -U bitsandbytes==0.41.3
# !pip install -U peft==0.8.2
# !pip install -U trl==0.7.10
# !pip install -U wandb==0.16.3
# !pip install -U huggingface_hub==0.20.3
# Out:
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to c:\users\chand\appdata\local\temp\pip-req-build-smn8lv3p
#   Resolved https://github.com/huggingface/transformers.git to commit 0290ec19c901adc0f1230ebdccad11c40af026f5
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: filelock in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers==4.39.0.dev0) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers==4.39.0.dev0) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers==4.39.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers==4.39.0.dev0) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers==4.39.0.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers==4.39.0.dev0) (2023.12.25)
# Requirement already satisfied: requests in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers==4.39.0.dev0) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers==4.39.0.dev0) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers==4.39.0.dev0) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers==4.39.0.dev0) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.0.dev0) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.0.dev0) (4.10.0)
# Requirement already satisfied: colorama in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from tqdm>=4.27->transformers==4.39.0.dev0) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->transformers==4.39.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->transformers==4.39.0.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->transformers==4.39.0.dev0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->transformers==4.39.0.dev0) (2024.2.2)
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git 'C:\Users\chand\AppData\Local\Temp\pip-req-build-smn8lv3p'
# Requirement already satisfied: accelerate==0.27.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (0.27.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from accelerate==0.27.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from accelerate==0.27.1) (24.0)
# Requirement already satisfied: psutil in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from accelerate==0.27.1) (5.9.8)
# Requirement already satisfied: pyyaml in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from accelerate==0.27.1) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from accelerate==0.27.1) (2.2.1)
# Requirement already satisfied: huggingface-hub in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from accelerate==0.27.1) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from accelerate==0.27.1) (0.4.2)
# Requirement already satisfied: filelock in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from torch>=1.10.0->accelerate==0.27.1) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from torch>=1.10.0->accelerate==0.27.1) (4.10.0)
# Requirement already satisfied: sympy in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from torch>=1.10.0->accelerate==0.27.1) (1.12)
# Requirement already satisfied: networkx in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from torch>=1.10.0->accelerate==0.27.1) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from torch>=1.10.0->accelerate==0.27.1) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from torch>=1.10.0->accelerate==0.27.1) (2024.2.0)
# Requirement already satisfied: requests in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from huggingface-hub->accelerate==0.27.1) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from huggingface-hub->accelerate==0.27.1) (4.66.2)
# Requirement already satisfied: colorama in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from tqdm>=4.42.1->huggingface-hub->accelerate==0.27.1) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from jinja2->torch>=1.10.0->accelerate==0.27.1) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->huggingface-hub->accelerate==0.27.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->huggingface-hub->accelerate==0.27.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->huggingface-hub->accelerate==0.27.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->huggingface-hub->accelerate==0.27.1) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from sympy->torch>=1.10.0->accelerate==0.27.1) (1.3.0)
# Requirement already satisfied: bitsandbytes==0.41.3 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (0.41.3)
# Requirement already satisfied: peft==0.8.2 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (0.8.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from peft==0.8.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from peft==0.8.2) (24.0)
# Requirement already satisfied: psutil in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from peft==0.8.2) (5.9.8)
# Requirement already satisfied: pyyaml in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from peft==0.8.2) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from peft==0.8.2) (2.2.1)
# Requirement already satisfied: transformers in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from peft==0.8.2) (4.39.0.dev0)
# Requirement already satisfied: tqdm in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from peft==0.8.2) (4.66.2)
# Requirement already satisfied: accelerate>=0.21.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from peft==0.8.2) (0.27.1)
# Requirement already satisfied: safetensors in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from peft==0.8.2) (0.4.2)
# Requirement already satisfied: huggingface-hub>=0.17.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from peft==0.8.2) (0.20.3)
# Requirement already satisfied: filelock in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from huggingface-hub>=0.17.0->peft==0.8.2) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from huggingface-hub>=0.17.0->peft==0.8.2) (2024.2.0)
# Requirement already satisfied: requests in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from huggingface-hub>=0.17.0->peft==0.8.2) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from huggingface-hub>=0.17.0->peft==0.8.2) (4.10.0)
# Requirement already satisfied: sympy in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from torch>=1.13.0->peft==0.8.2) (1.12)
# Requirement already satisfied: networkx in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from torch>=1.13.0->peft==0.8.2) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from torch>=1.13.0->peft==0.8.2) (3.1.3)
# Requirement already satisfied: colorama in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from tqdm->peft==0.8.2) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers->peft==0.8.2) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers->peft==0.8.2) (0.15.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from jinja2->torch>=1.13.0->peft==0.8.2) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->huggingface-hub>=0.17.0->peft==0.8.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->huggingface-hub>=0.17.0->peft==0.8.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->huggingface-hub>=0.17.0->peft==0.8.2) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->huggingface-hub>=0.17.0->peft==0.8.2) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from sympy->torch>=1.13.0->peft==0.8.2) (1.3.0)
# Requirement already satisfied: trl==0.7.10 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (0.7.10)
# Requirement already satisfied: torch>=1.4.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from trl==0.7.10) (2.2.1)
# Requirement already satisfied: transformers>=4.31.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from trl==0.7.10) (4.39.0.dev0)
# Requirement already satisfied: numpy>=1.18.2 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from trl==0.7.10) (1.26.4)
# Requirement already satisfied: accelerate in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from trl==0.7.10) (0.27.1)
# Requirement already satisfied: datasets in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from trl==0.7.10) (2.18.0)
# Requirement already satisfied: tyro>=0.5.11 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from trl==0.7.10) (0.7.3)
# Requirement already satisfied: filelock in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from torch>=1.4.0->trl==0.7.10) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from torch>=1.4.0->trl==0.7.10) (4.10.0)
# Requirement already satisfied: sympy in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from torch>=1.4.0->trl==0.7.10) (1.12)
# Requirement already satisfied: networkx in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from torch>=1.4.0->trl==0.7.10) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from torch>=1.4.0->trl==0.7.10) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from torch>=1.4.0->trl==0.7.10) (2024.2.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers>=4.31.0->trl==0.7.10) (0.20.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers>=4.31.0->trl==0.7.10) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers>=4.31.0->trl==0.7.10) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers>=4.31.0->trl==0.7.10) (2023.12.25)
# Requirement already satisfied: requests in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers>=4.31.0->trl==0.7.10) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers>=4.31.0->trl==0.7.10) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers>=4.31.0->trl==0.7.10) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from transformers>=4.31.0->trl==0.7.10) (4.66.2)
# Requirement already satisfied: docstring-parser>=0.14.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from tyro>=0.5.11->trl==0.7.10) (0.15)
# Requirement already satisfied: rich>=11.1.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from tyro>=0.5.11->trl==0.7.10) (13.7.1)
# Requirement already satisfied: shtab>=1.5.6 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from tyro>=0.5.11->trl==0.7.10) (1.7.1)
# Requirement already satisfied: colorama>=0.4.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from tyro>=0.5.11->trl==0.7.10) (0.4.6)
# Requirement already satisfied: psutil in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from accelerate->trl==0.7.10) (5.9.8)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from datasets->trl==0.7.10) (15.0.1)
# Requirement already satisfied: pyarrow-hotfix in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from datasets->trl==0.7.10) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from datasets->trl==0.7.10) (0.3.8)
# Requirement already satisfied: pandas in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from datasets->trl==0.7.10) (2.2.1)
# Requirement already satisfied: xxhash in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from datasets->trl==0.7.10) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from datasets->trl==0.7.10) (0.70.16)
# Requirement already satisfied: aiohttp in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from datasets->trl==0.7.10) (3.9.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from aiohttp->datasets->trl==0.7.10) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from aiohttp->datasets->trl==0.7.10) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from aiohttp->datasets->trl==0.7.10) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from aiohttp->datasets->trl==0.7.10) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from aiohttp->datasets->trl==0.7.10) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from aiohttp->datasets->trl==0.7.10) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->transformers>=4.31.0->trl==0.7.10) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->transformers>=4.31.0->trl==0.7.10) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->transformers>=4.31.0->trl==0.7.10) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->transformers>=4.31.0->trl==0.7.10) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.10) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.10) (2.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from jinja2->torch>=1.4.0->trl==0.7.10) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from pandas->datasets->trl==0.7.10) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from pandas->datasets->trl==0.7.10) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from pandas->datasets->trl==0.7.10) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from sympy->torch>=1.4.0->trl==0.7.10) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl==0.7.10) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets->trl==0.7.10) (1.16.0)
# Requirement already satisfied: wandb==0.16.3 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (0.16.3)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from wandb==0.16.3) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from wandb==0.16.3) (3.1.42)
# Requirement already satisfied: requests<3,>=2.0.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from wandb==0.16.3) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from wandb==0.16.3) (5.9.8)
# Requirement already satisfied: sentry-sdk>=1.0.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from wandb==0.16.3) (1.41.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from wandb==0.16.3) (0.4.0)
# Requirement already satisfied: PyYAML in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from wandb==0.16.3) (6.0.1)
# Requirement already satisfied: setproctitle in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from wandb==0.16.3) (1.3.3)
# Requirement already satisfied: setuptools in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from wandb==0.16.3) (68.2.2)
# Requirement already satisfied: appdirs>=1.4.3 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from wandb==0.16.3) (1.4.4)
# Requirement already satisfied: typing-extensions in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from wandb==0.16.3) (4.10.0)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from wandb==0.16.3) (4.25.3)
# Requirement already satisfied: colorama in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from Click!=8.0.0,>=7.1->wandb==0.16.3) (0.4.6)
# Requirement already satisfied: six>=1.4.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from docker-pycreds>=0.4.0->wandb==0.16.3) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from GitPython!=3.1.29,>=1.0.0->wandb==0.16.3) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests<3,>=2.0.0->wandb==0.16.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests<3,>=2.0.0->wandb==0.16.3) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests<3,>=2.0.0->wandb==0.16.3) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests<3,>=2.0.0->wandb==0.16.3) (2024.2.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.16.3) (5.0.1)
# Requirement already satisfied: huggingface_hub==0.20.3 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (0.20.3)
# Requirement already satisfied: filelock in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from huggingface_hub==0.20.3) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from huggingface_hub==0.20.3) (2024.2.0)
# Requirement already satisfied: requests in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from huggingface_hub==0.20.3) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from huggingface_hub==0.20.3) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from huggingface_hub==0.20.3) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from huggingface_hub==0.20.3) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from huggingface_hub==0.20.3) (24.0)
# Requirement already satisfied: colorama in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from tqdm>=4.42.1->huggingface_hub==0.20.3) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->huggingface_hub==0.20.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->huggingface_hub==0.20.3) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->huggingface_hub==0.20.3) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chand\miniconda3\envs\new_finetune\lib\site-packages (from requests->huggingface_hub==0.20.3) (2024.2.2)

# %%
# Code adapted from https://github.com/huggingface/trl/blob/main/examples/research_projects/stack_llama/scripts/supervised_finetuning.py
# and https://huggingface.co/blog/gemma-peft
import argparse
import multiprocessing
import os

import torch
import transformers
from transformers import Trainer
from accelerate import PartialState
from datasets import load_dataset
from peft import LoraConfig, TaskType, get_peft_model
from transformers import (
    AutoModelForCausalLM,
    BitsAndBytesConfig,
    logging,
    set_seed,
)
# from trl import SFTTrainer


def get_args():
    parser = argparse.ArgumentParser()

    parser.add_argument("--model_id", type=str, default="bigcode/starcoder2-3b")
    parser.add_argument("--dataset_name", type=str, default="the-stack-smol")
    parser.add_argument("--subset", type=str, default="data/rust")
    parser.add_argument("--split", type=str, default="train")
    parser.add_argument("--dataset_text_field", type=str, default="content")

    parser.add_argument("--max_seq_length", type=int, default=1024)
    parser.add_argument("--max_steps", type=int, default=1000)
    parser.add_argument("--micro_batch_size", type=int, default=1)
    parser.add_argument("--gradient_accumulation_steps", type=int, default=4)
    parser.add_argument("--weight_decay", type=float, default=0.01)
    parser.add_argument("--bf16", type=bool, default=True)

    parser.add_argument("--attention_dropout", type=float, default=0.1)
    parser.add_argument("--learning_rate", type=float, default=2e-4)
    parser.add_argument("--lr_scheduler_type", type=str, default="cosine")
    parser.add_argument("--warmup_steps", type=int, default=100)
    parser.add_argument("--seed", type=int, default=0)
    parser.add_argument("--output_dir", type=str, default="finetune_starcoder2")
    parser.add_argument("--num_proc", type=int, default=None)
    parser.add_argument("--push_to_hub", type=bool, default=True)
    return parser.parse_args(args=[])


def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )


def main(args):
    # config
    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.bfloat16,
    )
    lora_config = LoraConfig(
        r=8,
        target_modules=[
            "q_proj",
            "o_proj",
            "k_proj",
            "v_proj",
            "gate_proj",
            "up_proj",
            "down_proj",
        ],
        task_type="CAUSAL_LM",
    )

    # load model and dataset
    token = os.getenv("HF_TOKEN")
    print(args.model_id)
    model = AutoModelForCausalLM.from_pretrained(
        args.model_id,
        quantization_config=bnb_config,
        device_map={"": PartialState().process_index},
        attention_dropout=args.attention_dropout,
    )
    print_trainable_parameters(model)

    model = get_peft_model(model, lora_config)
    model.print_trainable_parameters()

    data = load_dataset(
        args.dataset_name,
        data_dir=args.subset,
        split=args.split,
        token=token,
        num_proc=args.num_proc if args.num_proc else multiprocessing.cpu_count(),
    )

    # setup the trainer
    trainer = Trainer(
        model=model,
        train_dataset=data,
        max_seq_length=args.max_seq_length,
        args=transformers.TrainingArguments(
            per_device_train_batch_size=args.micro_batch_size,
            gradient_accumulation_steps=args.gradient_accumulation_steps,
            warmup_steps=args.warmup_steps,
            max_steps=args.max_steps,
            learning_rate=args.learning_rate,
            lr_scheduler_type=args.lr_scheduler_type,
            weight_decay=args.weight_decay,
            bf16=args.bf16,
            logging_strategy="steps",
            logging_steps=10,
            output_dir=args.output_dir,
            optim="paged_adamw_8bit",
            seed=args.seed,
            run_name=f"train-{args.model_id.split('/')[-1]}",
            report_to="wandb",
        ),
        peft_config=lora_config,
        dataset_text_field=args.dataset_text_field,
    )

    # launch
    print("Training...")
    trainer.train()

    print("Saving the last checkpoint of the model")
    model.save_pretrained(os.path.join(args.output_dir, "final_checkpoint/"))
    if args.push_to_hub:
        trainer.push_to_hub("Upload model")
    print("Training Done! 💥")


args = get_args()
set_seed(args.seed)
os.makedirs(args.output_dir, exist_ok=True)

logging.set_verbosity_error()

main(args)
# Out:
# bigcode/starcoder2-3b
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1127             try:
# -> 1128                 config_class = CONFIG_MAPPING[config_dict["model_type"]]
#    1129             except KeyError:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/configuration_auto.py in __getitem__(self, key)
#     824         if key not in self._mapping:
# --> 825             raise KeyError(key)
#     826         value = self._mapping[key]
#
# KeyError: 'starcoder2'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-9933f56ddd67> in <cell line: 146>()
#     144 logging.set_verbosity_error()
#     145
# --> 146 main(args)
#
# <ipython-input-14-9933f56ddd67> in main(args)
#      85     token = os.getenv("HF_TOKEN")
#      86     print(args.model_id)
# ---> 87     model = AutoModelForCausalLM.from_pretrained(
#      88         args.model_id,
#      89         quantization_config=bnb_config,
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     519                 _ = kwargs.pop("quantization_config")
#     520
# --> 521             config, kwargs = AutoConfig.from_pretrained(
#     522                 pretrained_model_name_or_path,
#     523                 return_unused_kwargs=True,
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1128                 config_class = CONFIG_MAPPING[config_dict["model_type"]]
#    1129             except KeyError:
# -> 1130                 raise ValueError(
#    1131                     f"The checkpoint you are trying to load has model type `{config_dict['model_type']}` "
#    1132                     "but Transformers does not recognize this architecture. This could be because of an "
#
# ValueError: The checkpoint you are trying to load has model type `starcoder2` but Transformers does not recognize this architecture. This could be because of an issue with the checkpoint, or because your version of Transformers is out of date.

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("bigcode/starcoder2-3b")
model = AutoModelForCausalLM.from_pretrained("bigcode/starcoder2-3b")
device = "cuda"

inputs = tokenizer.encode("def print_hello_world():", return_tensors="pt").to(device)
outputs = model.generate(inputs)
print(tokenizer.decode(outputs[0]))
